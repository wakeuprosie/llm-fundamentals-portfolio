# %% [markdown]
# <a href="https://colab.research.google.com/github/wakeuprosie/basic-bpe-tokenizer/blob/main/tokenization_comparisons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tiktoken
import pandas as pd

#initiate Chat GPT-4's tokenizer 'tiktoken'
enc = tiktoken.get_encoding("cl100k_base")

#varied query input examples to demonstrate differences in tokenization
examples = {
    "Plain english": "I’m a regular person trying to understand tokenization thanks to Andrej Karpathy’s awesome resources.",
    "Noisy user text": "heyyyy did you get tix for the BTS concert??! 🤩",
    "JSON": '{"product":"popcorn","calories":90,"isLowCalorie":true}',
    "Code": 'def calculate_total():',
    "Multilingual text": "是时候学中文了！你好。"
}

#display tokenized text examples in a table
table = []

for type, text in examples.items():
  token_ids = enc.encode(text)
  table.append(
      {
          "input_type": type,
          "input_text": text,
          "num_tokens": len(token_ids),
          "tokens": token_ids
      }
  )

dt = pd.DataFrame(table)

dt.sort_values("num_tokens", ascending=False, inplace=True)

pd.set_option('display.max_colwidth', None)

dt
# Out:
#           input_type  \
# 0      Plain english
# 2               JSON
# 1    Noisy user text
# 4  Multilingual text
# 3               Code
#
#                                                                                               input_text  \
# 0  I’m a regular person trying to understand tokenization thanks to Andrej Karpathy’s awesome resources.
# 2                                                {"product":"popcorn","calories":90,"isLowCalorie":true}
# 1                                                        heyyyy did you get tix for the BTS concert??! 🤩
# 4                                                                                            是时候学中文了！你好。
# 3                                                                                 def calculate_total():
#
#    num_tokens  \
# 0          21
# 2          18
# 1          16
# 4          12
# 3           4
#
#                                                                                                                   tokens
# 0  [40, 4344, 264, 5912, 1732, 4560, 311, 3619, 4037, 2065, 9523, 311, 27525, 73, 13528, 2398, 88, 753, 12738, 5070, 13]
# 2             [5018, 3107, 3332, 8539, 39730, 2247, 5531, 2490, 794, 1954, 1359, 285, 25162, 9027, 30303, 794, 1904, 92]
# 1                                [383, 15110, 1550, 499, 636, 259, 953, 369, 279, 83168, 21497, 7801, 0, 11410, 97, 102]
# 4                                       [21043, 13646, 20022, 247, 48864, 16325, 17161, 35287, 6447, 57668, 53901, 1811]
# 3                                                                                              [755, 11294, 11017, 4658]
